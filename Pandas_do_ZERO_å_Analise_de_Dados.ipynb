# %% [markdown]
# <a href="https://colab.research.google.com/github/cabralana/pandas-analise-de-dados/blob/main/Pandas_do_ZERO_%C3%A5_Analise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **ESTUDO - COVID19**  📊

# %% [markdown]
# ## **INSTALAÇÃO PANDAS - GOOGLE COLAB**

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## **IMPORTAÇÃO PANDAS E VERIFICAR VERSÃO**

# %%
import pandas
pandas.__version__
# Out:
# '1.3.5'

# %% [markdown]
# ## **CONVENÇÅO DE IMPORTAÇÅO - PD**

# %%
import pandas as pd

# %% [markdown]
# ## **AS DUAS PRINCIPAIS ESTRUTURAS DE DADOS DO PANDAS**
#
#
#
# *   Que tipo de dados os pandas manipulam?
# 1.   DataFrames
# 2.   Series

# %% [markdown]
# ***SERIES***:
#
#
# > Séries é uma matriz rotulada unidimensional capaz de conter qualquer tipo de dados (inteiros, strings, números de ponto flutuante, objetos Python, etc.) Os rótulos dos eixos são chamados coletivamente de índice.
#
# > O método básico para criar uma série é:

# %%
s1 = pd.Series(['a', 'b', 'c', 'd'], index=[1, 2, 3, 4], name='Random')
s2 = pd.Series(['e', 'f', 'g', 'h'], index=[1, 2, 3, 4], name='Random2')

# %% [markdown]
# ***DATAFRAMES***:
#
# > DataFrame é uma estrutura de dados rotulada bidimensional com colunas de tipos potencialmente diferentes. É como uma planilha ou tabela SQL, ou um dicionário de objetos Series. Geralmente é o objeto pandas mais comumente usado. Como o Series, o DataFrame aceita muitos tipos diferentes de entradas:

# %%
pd.DataFrame([s1, s2])
# Out:
#          1  2  3  4
# Random   a  b  c  d
# Random2  e  f  g  h

# %% [markdown]
# ##**ABRINDO E EXPORTANDO DADOS - DRIVE**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# Copiar caminho do arquivo CSV no drive 

covid = pd.read_csv("/content/drive/MyDrive/part-00000-06f3a84d-a1d2-47ef-a5ea-1a21a9cc4526.c000.csv", sep=';')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
covid
# Out:
#                                        document_id  \
# 0        20a3768c-008d-422c-9a7d-a53caeb53f50-i0b0
# 1        cf3cbf86-2c44-47fc-bc5e-56cd76074a48-i0b0
# 2        20a38029-061b-4b50-b15a-311c46ea3ead-i0b0
# 3        cf5b82a5-07d8-429a-9c70-757c8aadf850-i0b0
# 4        20e7ae02-cf6c-4a99-8482-0485a8953344-i0b0
# ...                                            ...
# 2321129  cefffbbf-24a1-465e-b51f-a6337fb97269-i0b0
# 2321130  cf008a5f-6f85-4fbb-a1a1-72c549b89aaa-i0b0
# 2321131  cf020ad1-7e3a-4385-955e-2b8b59a583ba-i0b0
# 2321132  cf1de2cd-c8e6-4ac8-b8e3-9479cbc54dac-i0b0
# 2321133  cf33ca0e-a1cb-4398-ba75-b0e175e51992-i0b0
#
#                                                paciente_id  paciente_idade  \
# 0        cc7ce1d8df5f968eea012c162d02555f538cfef5eb8e09...            48.0
# 1        86b3eec0f2e534236e381634c6c43b4f86148ed2039a26...            54.0
# 2        edfe3cab2adcd5a5280cd689fdbcf52261af7052542876...            60.0
# ...

# %%
# covid.to_csv("covid.csv")

# %% [markdown]
# ###**VISUALIZANDO DADOS**
#
#
#
# 1. Head
# 2. Tail
# 3. Index
# 4. Columns
# 5. Describe
# 6. Transposta

# %%
covid.head()
# Out:
#                                  document_id  \
# 0  20a3768c-008d-422c-9a7d-a53caeb53f50-i0b0
# 1  cf3cbf86-2c44-47fc-bc5e-56cd76074a48-i0b0
# 2  20a38029-061b-4b50-b15a-311c46ea3ead-i0b0
# 3  cf5b82a5-07d8-429a-9c70-757c8aadf850-i0b0
# 4  20e7ae02-cf6c-4a99-8482-0485a8953344-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  cc7ce1d8df5f968eea012c162d02555f538cfef5eb8e09...            48.0
# 1  86b3eec0f2e534236e381634c6c43b4f86148ed2039a26...            54.0
# 2  edfe3cab2adcd5a5280cd689fdbcf52261af7052542876...            60.0
# 3  82564c43253561e126b11d057f98778772498f3a807567...            27.0
# 4  3afdefba18d95182770c3f47390205161352cc0da0e224...            42.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              1973-09-04                          M                      1.0
# 1              1968-01-15                          F                      1.0
# ...

# %%
covid[covid.paciente_endereco_nmMunicipio.isnull()== False]
# Out:
#                                        document_id  \
# 0        20a3768c-008d-422c-9a7d-a53caeb53f50-i0b0
# 1        cf3cbf86-2c44-47fc-bc5e-56cd76074a48-i0b0
# 2        20a38029-061b-4b50-b15a-311c46ea3ead-i0b0
# 3        cf5b82a5-07d8-429a-9c70-757c8aadf850-i0b0
# 4        20e7ae02-cf6c-4a99-8482-0485a8953344-i0b0
# ...                                            ...
# 2321129  cefffbbf-24a1-465e-b51f-a6337fb97269-i0b0
# 2321130  cf008a5f-6f85-4fbb-a1a1-72c549b89aaa-i0b0
# 2321131  cf020ad1-7e3a-4385-955e-2b8b59a583ba-i0b0
# 2321132  cf1de2cd-c8e6-4ac8-b8e3-9479cbc54dac-i0b0
# 2321133  cf33ca0e-a1cb-4398-ba75-b0e175e51992-i0b0
#
#                                                paciente_id  paciente_idade  \
# 0        cc7ce1d8df5f968eea012c162d02555f538cfef5eb8e09...            48.0
# 1        86b3eec0f2e534236e381634c6c43b4f86148ed2039a26...            54.0
# 2        edfe3cab2adcd5a5280cd689fdbcf52261af7052542876...            60.0
# ...

# %%
covid.tail()
# Out:
#                                        document_id  \
# 2321129  cefffbbf-24a1-465e-b51f-a6337fb97269-i0b0
# 2321130  cf008a5f-6f85-4fbb-a1a1-72c549b89aaa-i0b0
# 2321131  cf020ad1-7e3a-4385-955e-2b8b59a583ba-i0b0
# 2321132  cf1de2cd-c8e6-4ac8-b8e3-9479cbc54dac-i0b0
# 2321133  cf33ca0e-a1cb-4398-ba75-b0e175e51992-i0b0
#
#                                                paciente_id  paciente_idade  \
# 2321129  4ee96a5ba1e5cc11daba37bf068e9c10e313c993e23164...            61.0
# 2321130  3d88a65bf9cfdf3f36aa1dd97085a1505bd6814bdab5ea...            23.0
# 2321131  3130e621d40ba33023898ced0c9f05f5f1d4fdcee77000...            39.0
# 2321132  b3b9baf7d186a48fa33879ce4cd8c41a323261f28d95c3...            70.0
# 2321133  3f3e46bd564a3afd24d3ec5ad818f37fcad0eaa12dfa87...            50.0
#
#         paciente_dataNascimento paciente_enumSexoBiologico  \
# 2321129              1960-12-10                          M
# 2321130              1998-05-25                          M
# ...

# %%
covid.index
# Out:
# RangeIndex(start=0, stop=2321134, step=1)

# %%
covid.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
covid.columns.values
# Out:
# array(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade',
#        'estabelecimento_valor', 'estabelecimento_razaoSocial',
#        'estalecimento_noFantasia', 'estabelecimento_municipio_codigo',
#        'estabelecimento_municipio_nome', 'estabelecimento_uf',
#        'vacina_grupoAtendimento_codigo', 'vacina_grupoAtendimento_nome',
#        'vacina_categoria_codigo', 'vacina_categoria_nome', 'vacina_lote',
#        'vacina_fabricante_nome', 'vacina_fabricante_referencia',
#        'vacina_dataAplicacao', 'vacina_descricao_dose', 'vacina_codigo',
#        'vacina_nome', 'sistema_origem'], dtype=object)

# %%
covid.describe()
# Out:
#        paciente_idade  paciente_racaCor_codigo  estabelecimento_valor  \
# count    2.321119e+06             2.321117e+06           2.321134e+06
# mean     4.091391e+01             4.055644e+01           2.020331e+06
# std      1.910266e+01             4.713566e+01           3.317549e+06
# min      0.000000e+00             1.000000e+00           1.045600e+04
# 25%      2.600000e+01             3.000000e+00           1.090100e+04
# 50%      4.000000e+01             4.000000e+00           1.115000e+04
# 75%      5.500000e+01             9.900000e+01           3.254887e+06
# max      1.210000e+02             9.900000e+01           9.768637e+06
#
#        estabelecimento_municipio_codigo  vacina_grupoAtendimento_codigo  \
# count                         2321134.0                    2.320318e+06
# mean                           530010.0                    3.482534e+03
# std                                 0.0                    5.640908e+04
# ...

# %%
covid.T
# Out:
#                                                                                     0        \
# document_id                                       20a3768c-008d-422c-9a7d-a53caeb53f50-i0b0
# paciente_id                               cc7ce1d8df5f968eea012c162d02555f538cfef5eb8e09...
# paciente_idade                                                                         48.0
# paciente_dataNascimento                                                          1973-09-04
# paciente_enumSexoBiologico                                                                M
# paciente_racaCor_codigo                                                                 1.0
# paciente_racaCor_valor                                                               BRANCA
# paciente_endereco_coIbgeMunicipio                                                    530010
# paciente_endereco_coPais                                                                 10
# ...

# %% [markdown]
# ###**SELECIONANDO DADOS**

# %%
covid[5:10]
# Out:
#                                  document_id  \
# 5  cf5f5c66-7df6-4361-a7c0-1a449f7fe59a-i0b0
# 6  20f2f786-9811-4eef-b780-16245b451349-i0b0
# 7  cf67d0ed-1bee-405a-b4b6-39444f17dabe-i0b0
# 8  20f302d8-8287-4003-a85e-f5453323c472-i0b0
# 9  cf6d92f5-7425-4715-8e62-87416d246548-i0b0
#
#                                          paciente_id  paciente_idade  \
# 5  d0a08553ac5e00637e900e3455679f94b5944311b0a55c...            29.0
# 6  364a1b8d866c8666ac15196b74876aad3b1d23ff0f49e0...            74.0
# 7  c6895c14cce84fbf4272558e7bf15759a4212543ff1591...            17.0
# 8  419b2ce9492d9c1f6a078b6715a8a0fd2e7dd83db9cdbe...            49.0
# 9  6d441bae989daeaaad08de31c4ac7368657e3d36b2a982...            24.0
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 5              1992-05-03                          F                      3.0
# 6              1946-04-10                          M                      1.0
# ...

# %%
covid["vacina_descricao_dose"]
# Out:
# 0             2ª Dose
# 1          2º Reforço
# 2             1ª Dose
# 3             Reforço
# 4             1ª Dose
#               ...
# 2321129    2º Reforço
# 2321130       1ª Dose
# 2321131    2º Reforço
# 2321132       2ª Dose
# 2321133       1ª Dose
# Name: vacina_descricao_dose, Length: 2321134, dtype: object

# %%
covid.loc[:,["vacina_fabricante_nome", "paciente_idade"]]
# Out:
#         vacina_fabricante_nome  paciente_idade
# 0          ASTRAZENECA/FIOCRUZ            48.0
# 1                       PFIZER            54.0
# 2          ASTRAZENECA/FIOCRUZ            60.0
# 3                       PFIZER            27.0
# 4             SINOVAC/BUTANTAN            42.0
# ...                        ...             ...
# 2321129                JANSSEN            61.0
# 2321130            ASTRAZENECA            23.0
# 2321131                JANSSEN            39.0
# 2321132       SINOVAC/BUTANTAN            70.0
# 2321133    ASTRAZENECA/FIOCRUZ            50.0
#
# [2321134 rows x 2 columns]

# %%
covid[1000:2000], ["paciente_idade","paciente_dataNascimento"]
# Out:
# (                                    document_id  \
#  1000  321f0cab-7b5e-4c17-bd8a-3f6acb69ef62-i0b0
#  1001  e24d2afa-0c41-4ea9-8824-9edc9461b32d-i0b0
#  1002  3225fe33-cd08-45fd-9dca-db13c7367039-i0b0
#  1003  e25e0173-28fb-4834-aa80-673ddce514c4-i0b0
#  1004  3228db3d-5db6-409f-9741-d2d90ed40bd0-i0b0
#  ...                                         ...
#  1995  f474506d-6f54-4af7-bb1f-983bf5222e35-i0b0
#  1996  45b48ad1-cc16-49b6-abe5-7b2fe09b744c-i0b0
#  1997  f477ce45-a57e-4156-a56b-5d92c310e43d-i0b0
#  1998  45b5cb6e-29c2-41c1-81af-f99b9e9855b4-i0b0
#  1999  f480e277-ba72-4834-a16d-e374a9068ae1-i0b0
#
#                                              paciente_id  paciente_idade  \
#  1000  897751b5bad627be39bcccd5aa8420a0f5c1201e4d8c5c...            45.0
#  1001  92b7075db88b112a3a11e2ca327d33188dcf35bcbf4ab6...            14.0
#  1002  f63452cee770ea391696d32484a54d5d634931c6a89500...            18.0
#  1003  9b36f60162038d269631416c3ed1c171058e450c89baad...            85.0
# ...

# %%
covid.iloc[1000]
# Out:
# document_id                                         321f0cab-7b5e-4c17-bd8a-3f6acb69ef62-i0b0
# paciente_id                                 897751b5bad627be39bcccd5aa8420a0f5c1201e4d8c5c...
# paciente_idade                                                                           45.0
# paciente_dataNascimento                                                            1976-10-31
# paciente_enumSexoBiologico                                                                  M
# paciente_racaCor_codigo                                                                   1.0
# paciente_racaCor_valor                                                                 BRANCA
# paciente_endereco_coIbgeMunicipio                                                      431490
# paciente_endereco_coPais                                                                   10
# paciente_endereco_nmMunicipio                                                    PORTO ALEGRE
# ...

# %%
covid.iloc[:, 2:3]
# Out:
#          paciente_idade
# 0                  48.0
# 1                  54.0
# 2                  60.0
# 3                  27.0
# 4                  42.0
# ...                 ...
# 2321129            61.0
# 2321130            23.0
# 2321131            39.0
# 2321132            70.0
# 2321133            50.0
#
# [2321134 rows x 1 columns]

# %% [markdown]
# ###**INDEXAÇÅO BOOLEANA**

# %%
covid[(covid['vacina_codigo'] > 86) & (covid['vacina_codigo'] < 90)]
# Out:
#                                        document_id  \
# 1        cf3cbf86-2c44-47fc-bc5e-56cd76074a48-i0b0
# 3        cf5b82a5-07d8-429a-9c70-757c8aadf850-i0b0
# 5        cf5f5c66-7df6-4361-a7c0-1a449f7fe59a-i0b0
# 7        cf67d0ed-1bee-405a-b4b6-39444f17dabe-i0b0
# 8        20f302d8-8287-4003-a85e-f5453323c472-i0b0
# ...                                            ...
# 2321125  ceed13e5-86bd-4c6b-873a-1129f1c951bc-i0b0
# 2321128  cefc833e-b3f0-4555-bece-cb7382f06706-i0b0
# 2321129  cefffbbf-24a1-465e-b51f-a6337fb97269-i0b0
# 2321130  cf008a5f-6f85-4fbb-a1a1-72c549b89aaa-i0b0
# 2321131  cf020ad1-7e3a-4385-955e-2b8b59a583ba-i0b0
#
#                                                paciente_id  paciente_idade  \
# 1        86b3eec0f2e534236e381634c6c43b4f86148ed2039a26...            54.0
# 3        82564c43253561e126b11d057f98778772498f3a807567...            27.0
# 5        d0a08553ac5e00637e900e3455679f94b5944311b0a55c...            29.0
# ...

# %% [markdown]
# ###**OPERAÇOES**
#
#
#
# *  mean
# *  apply
# *  value_counts

# %%
covid['paciente_racaCor_codigo'].mean()
# Out:
# 40.55643985201952

# %%
covid['vacina_codigo'].value_counts()
# Out:
# 87    1071558
# 85     570837
# 86     431550
# 88     162686
# 99      43448
# 89      40961
# 98         94
# Name: vacina_codigo, dtype: int64

# %%
covid['vacina_codigo'].value_counts(normalize=True)
# Out:
# 87    0.461653
# 85    0.245930
# 86    0.185922
# 88    0.070089
# 99    0.018718
# 89    0.017647
# 98    0.000040
# Name: vacina_codigo, dtype: float64

# %% [markdown]
# ###**Funcao apply** - exemplo:
#
#
#
# covid[["casosNovos", "obitosNovos"]].apply(lambda x: x.max())

# %% [markdown]
# ### **GRÁFICOS**

# %%
covid['paciente_idade'].plot(kind='hist')

# %% [markdown]
# ###**AGRUPAMENTO** (Group By)

# %%
covid.groupby(['vacina_fabricante_nome']).mean()['paciente_idade']
# Out:
# vacina_fabricante_nome
# ASTRAZENECA                                  43.340356
# ASTRAZENECA/FIOCRUZ                          49.361124
# FUNDACAO OSWALDO CRUZ                        35.000000
# JANSSEN                                      43.932469
# JANSSEN PHARMACEUTICA NV                     60.000000
# PFIZER                                       37.502310
# PFIZER - PEDI?TRICA                           7.524691
# PFIZER - PEDIÁTRICA                           7.112009
# PFIZER MANUFACTURING BELGIUM NV - BELGICA    35.857143
# Pendente Identifica??o                        6.358696
# Pendente Identificação                        7.910669
# SINOVAC                                      10.404255
# SINOVAC/BUTANTAN                             40.193100
# Name: paciente_idade, dtype: float64

# %% [markdown]
# ###**VALORES AUSENTES**
#
#
#
# * isnull() - gere uma mascara booleana indicando valores ausentes
# * notnull() - oposto de isnull()
# * dropna() - retorna uma versao filtrada dos dados
# * fillna() - retorna uma copia dos dados com os valores ausentes preenchidos ou imputados

# %% [markdown]
# ### **IMPORTANDO DADOS PARA CRIAÇAO DE MAPAS**

# %%
municipios = pd.read_csv('/content/drive/MyDrive/municipios_dados.csv')

# %%
municipios
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf
# 0            52
# 1            31
# 2            52
# 3            31
# 4            15
# ...         ...
# ...

# %%
municipios.head()
# Out:
#    codigo_ibge                 nome  latitude  longitude  capital  codigo_uf
# 0      5200050      Abadia de Goiás -16.75730   -49.4412        0         52
# 1      3100104  Abadia dos Dourados -18.48310   -47.3916        0         31
# 2      5200100            Abadiânia -16.19700   -48.7057        0         52
# 3      3100203               Abaeté -19.15510   -45.4444        0         31
# 4      1500107           Abaetetuba  -1.72183   -48.8788        0         15

# %%
# !pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os
import folium

print(folium.__version__)
# Out:
# 0.12.1.post1

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/municipios_dados.csv", delimiter=";")

# %%
# Abadia de Goiás 
mapa = folium.Map(location=[-16.75730,-49.4412])

# %%
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map(
    location=[-16.75730, -49.4412],
    tiles ='Stamen Terrain'
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# # continuar - reorganizar os dados
